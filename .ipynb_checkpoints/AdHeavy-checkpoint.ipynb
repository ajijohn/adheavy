# %% [markdown]
# # AdHeavy Work

# %% [markdown]
# Today's workshop will address various concepts in Natural Language Processing, primarily through the use of NTLK. A fundmental understanding of Python is necessary. We will cover:
#
# 1. Preparing your own corpus
# 2. Tagging
# 3. Chunking
# 4. Document classification
#
# You will need:
#
# * NLTK ( \$ pip install nltk)
# * Brown corpus from NLTK ( >>> nltk.download() )
# * Punkt tokenizer from NLTK ( >>> nltk.download() )
# * Movie reviews corpus from NLTK ( >>> nltk.download() )
# * Punkt tokenizer from NLTK ( >>> nltk.download() )
# * BeautifulSoup ( \$ pip install beautifulsoup4)
#
# This workshop will further help to solidfy understandings of regex and list comprehensions.

# %% [markdown]
# Much of today's work will be adapted, or taken directly, from the NLTK book found here: http://www.nltk.org/book/ . The guide for BeautifulSoup is here: http://www.crummy.com/software/BeautifulSoup/bs4/doc/ . For further explanation of grammars see *Data Science from Scratch*: http://shop.oreilly.com/product/0636920033400.do .

# %% [markdown]
# # 1) Preparing your own corpus

# %% [markdown]
# We are going to take Jonathan Swift's *Gulliver's Travels* from archive.org to use as our text throughout today's workshop. Although we will utilize pre-made corpora to explore more robust options, it is useful to know how to clean your own text files you may have, create your own corpus, declare it properly, and run analyses, so we will start from scratch.

# %% [markdown]
# ## String manipulation and cleaning

# %% [markdown]
# Let's first use Beautiful Soup to grab only the text. There are packages that exist to clean texts from standard sites such as a Gutenberg package for gutenberg.org, but today we'll clean it as best we can manually:

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.google.com/nwshp?hl=en&tab=wn&ei=LW0cV5TRMM2IjwOs44CoCQ&ved=0EKkuCAUoBQ"
#"https://ia801404.us.archive.org/2/items/gulliverstravels17157gut/17157-h/17157-h.htm"

f = requests.get(url)
html = f.content

print (f.content)
# Out:
# b'<!DOCTYPE HTML><html ><head><meta name="apple-itunes-app" content="app-id=913753848"><meta http-equiv="X-UA-Compatible" content="IE=8,IE=9"><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta content="origin" name="referrer"><meta name="description" content="Comprehensive up-to-date news coverage, aggregated from sources all over the world by Google News."/><title>Google News</title><link href="https://ssl.gstatic.com/news-static/img/favicon.ico" rel="shortcut icon"/><link rel="alternate" type="application/rss+xml" href="http://news.google.com/news?cf=all&hl=en&pz=1&ned=us&topic=h&num=3&output=rss"/><script type="text/javascript">(function (){ (function(){function e(a){this.t={};this.tick=function(a,c,b){this.t[a]=[void 0!=b?b:(new Date).getTime(),c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(d){}};this.tick("start",null,a)}var a;window.performance&&(a=window.performance.timing);var f=a?new e(a.responseStart):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart,d=a.responseStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",\nd),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})(); })()\n</script><script type="text/javascript">(function (){ if("#changed"==window.location.hash){var a=window.location.href,a=a.substr(0,a.indexOf("#")),b=[];if(-1<a.indexOf("?"))for(var c=a.substring(a.indexOf("?")+1).split("&"),d=0;d<c.length;d++)"zx="!=c[d].substring(0,3)&&"pz="!=c[d].substring(0,3)&&"shid="!=c[d].substring(0,5)&&b.push(c[d]);b.push("pz=1");b.push("zx="+Math.random());window.location=window.location.pathname+"?"+b.join("&")}try{window.newspm={},window.newspm.st=(new Date).getTime()}catch(e){}; })()\n</script><script type="text/javascript">NEWS_logErrors = true</script><script type="text/javascript">\n    window.__GOOGLEAPIS = window.__GOOGLEAPIS || {};\n    window.__GOOGLEAPIS.gwidget = window.__GOOGLEAPIS.gwidget || {};\n    window.__GOOGLEAPIS.gwidget.lang = \'en\'</script><style type="text/css">#cachedcsstestdiv{cursor:text}.goog-inline-block{display:inline-block}.inline-block{display:inline-block;position:relative}.ds1,.ds2,.ds3{border-right:1px solid #e7e7e7;z-index:50}.ds1{height:32px}.ds2{height:25px}.ds3{height:22px}.lsbb1,.lsbb2,.lsbb3{background:#eee none repeat scroll 0 0;border-color:#ccc #999 #999;border-style:solid;border-width:1px}.lsbb1{height:30px}.lsbb2{height:23px}.lsbb3{height:20px}.lsb1,.lsb2{border:medium none;cursor:pointer;font-family:arial,sans-serif;margin:0;vertical-align:top;position:relative}.lsb3{background-position:center bottom;border:medium none;cursor:pointer;font-family:arial,sans-serif;margin:0;vertical-align:top;position:relative}.lsb1:active,.lsb2:active{background:#ccc none repeat scroll 0 0}.lsb1,.lsb2{background-position:bottom center}.lsb1{height:30px;font-size:15px}.lsb2{height:23px;font-size:12px}.lsb3{height:20px;font-size:11px}.r{padding:0}.search-the-web{margin-left:4px}.main-pane b{font-weight:normal}.clearhack,.single-section{overflow:hidden;_width:100%}.clearheader,.clearfooter{clear:both}.ff-hack{overflow:auto}.main-pane .centered{text-align:left}.footer{max-width:1400px}.story{zoom:1}.small-story .title{font-size:13px;line-height:16px}.small-story .title a{padding-right:5px}.small-story .moreLinks .more-coverage-text{float:none}.source{white-space:nowrap;color:#767676}.pinning-enabled .left-nav-pinned{background:#fff none repeat scroll 0 0;position:fixed;top:0;z-index:99}.pinning-enabled #nav-menu-wrapper{overflow:hidden;padding:1px 16px 16px 0}.pinning-enabled #nav- ...

# %% [markdown]
# Create bs object and trim:

# %%
#clean and extract only raw text 
bspage = BeautifulSoup(html, "html.parser") #or "html.parser"
#find all the links

#get list of http urls to study 
httplinks = []
for link in bspage.find_all('a'):
    if str(link.get('href')).startswith('http'):
        httplinks.append(link.get('href'))
    
#httplinks = [link for (link) in bspage.find_all('a') if link.get('href').startswith('http') link.get('href')]

print(httplinks)
    
#rawtext = BeautifulSoup.get_text(bspage)
# could not see her till she arose, having been so long used to stand with
# my head and eyes erect to above sixty feet; and then I went to take her
# up with one hand by the waist. I looked down upon the servants, and one
# or two friends who were in the house, as if they had been pygmies, and I
# a giant. I told my wife she had been too thrifty, for I found she had
# starved herself and her daughter to nothing. In short, I behaved myself
# so unaccountably, that they were all of the captain's opinion when he
# first saw me, and concluded I had lost my wits. This I mention as an
# instance of the great power of habit and prejudice.
# In a little time, I and my family and friends came to a right
# understanding: but my wife protested I should never go to sea any more;
# although my evil destiny so ordered, that she had not power to hinder
# me, as the reader may know hereafter. In the meantime I here conclude
# the second part of my unfortunate voyages.

# %% [markdown]
# Let's save this text so we can read it in the corpus later:

# %%
import codecs
with codecs.open("gulliver.txt", "w","utf-8") as f:
    f.write(gtravels)

# %% [markdown]
# ## Declaring a corpus in NLTK

# %% [markdown]
# While you can use NLTK on strings and lists of sentences, it's better to formally declare your corpus.

# %%
from nltk.corpus import PlaintextCorpusReader

corpus_root = "" #rel. path
my_texts = PlaintextCorpusReader(corpus_root, '.*txt')

# %% [markdown]
# We now have a text corpus, on which we can run all the basic methods you learned in the introductory sequence. To list all the files in our corpus:

# %%
my_texts.fileids()
# Out:
# ['gulliver.txt']

# %% [markdown]
# We can also extract either all the words or all the sentences in list format:

# %%
my_texts.words('gulliver.txt')
# Out:
# ['My', 'father', 'had', 'a', 'small', 'estate', 'in', ...]

# %%
gsents = my_texts.sents('gulliver.txt')
print (gsents)
# Out:
# [['My', 'father', 'had', 'a', 'small', 'estate', 'in', 'Nottinghamshire', ';', 'I', 'was', 'the', 'third', 'of', 'five', 'sons', '.'], ['He', 'sent', 'me', 'to', 'Emmanuel', 'College', 'in', 'Cambridge', 'at', 'fourteen', 'years', 'old', ',', 'where', 'I', 'resided', 'three', 'years', ',', 'and', 'applied', 'myself', 'close', 'to', 'my', 'studies', ';', 'but', 'the', 'charge', 'of', 'maintaining', 'me', ',', 'although', 'I', 'had', 'a', 'very', 'scanty', 'allowance', ',', 'being', 'too', 'great', 'for', 'a', 'narrow', 'fortune', ',', 'I', 'was', 'bound', 'apprentice', 'to', 'Mr', '.', 'James', 'Bates', ',', 'an', 'eminent', 'surgeon', 'in', 'London', ',', 'with', 'whom', 'I', 'continued', 'four', 'years', ';', 'and', 'my', 'father', 'now', 'and', 'then', 'sending', 'me', 'small', 'sums', 'of', 'money', ',', 'I', 'laid', 'them', 'out', 'in', 'learning', 'navigation', ',', 'and', 'other', 'parts', 'of', 'the', 'mathematics', 'useful', 'to', 'those', 'who', 'intend', 'to', 'travel', ',', 'as', 'I', 'always', 'believed', 'it', 'would', 'be', ',', 'some', 'time', 'or', 'other', ',', 'my', 'fortune', 'to', 'do', '.'], ...]

# %% [markdown]
# We now have a corpus, or text, from which we can get any of the statistics you learned in Day 3 of the Python workshop. We will review some of these functions once we get some more information

# %% [markdown]
# # 2) Tagging

# %% [markdown]
# There are many situations, in which "tagging" words (or really anything) may be useful in order to determine or calculate trends, or for further text analysis to extract meaning. We will cover 3 methods of tagging: simple regex, n-gram, and Brill transformation based tagging. Although they will not be covered today, HMM, CRF, and neural networks will be briefly alluded to as additional machine learning models.
#
# It is important to note that in Natural Language Processing (NLP), POS (Part of Speech) tagging is the most common use for tagging, but the actual tag can be anything. Other applications include sentiment analysis and NER (Named Entity Recognition). Tagging is simply labeling a word to a specific category via a tuple.
#
# Nevertheless, for training more advanced tagging models, POS tagging is nearly essential. If you are defining a machine learning model to predict patterns in your text, these patterns will most likley rely on, among other things, POS features. You will therefore first tag POS and then use the POS as a feature in your model.

# %% [markdown]
# ## On a low-level

# %% [markdown]
# Tagging is creating a tuple of (word, tag) for every word in a text or corpus. For example: "My name is Chris" may be tagged for POS as:

# %% [markdown]
# My/PossessivePronoun name/Noun is/Verb Chris/ProperNoun ./Period
#
# *NB: type 'nltk.data.path' to find the path on your computer to your downloaded nltk corpora. You can explore these files to see how large corpora are formatted.*

# %% [markdown]
# You'll notice how the text is annotated, using a forward slash to match the word to its tag. So how can we get this to a useful form for Python?

# %%
from nltk.tag import str2tuple

line = "My/Possessive_Pronoun name/Noun is/Verb Chris/Proper_Noun ./Period"
tagged_sent = [str2tuple(t) for t in line.split()]

print (tagged_sent)
# Out:
# [('My', 'POSSESSIVE_PRONOUN'), ('name', 'NOUN'), ('is', 'VERB'), ('Chris', 'PROPER_NOUN'), ('.', 'PERIOD')]

# %% [markdown]
# Further analysis of tags with NLTK requires a *list* of sentences, otherwise you will get an index error on higher level methods.

# %% [markdown]
# Naturally, these tags are a bit verbose, the standard tagging conventions follow the Penn Treebank (more in a second): https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %% [markdown]
# ## Working with a tagged corpus

# %% [markdown]
# Now that we know how tagging works, let's import a tagged corpus from the NLTK database and see what we can do.

# %%
from nltk.corpus import brown #if you don't have this downloaded, type nltk.download()
brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %% [markdown]
# *NB: the argument tagset = "universal" simplifies the tagset.*

# %% [markdown]
# Let's find the most frequent parts of speech in the corpus:

# %%
import nltk

brown_news_tagged = brown.tagged_words(categories='news') #not universal tagset
#tag frequency distribution
#AT -article
#NN
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [('NN', 13162),
#  ('IN', 10616),
#  ('AT', 8893),
#  ('NP', 6866),
#  (',', 5133),
#  ('NNS', 5066),
#  ('.', 4452),
#  ('JJ', 4392),
#  ('CC', 2664),
#  ('VBD', 2524),
#  ('NN-TL', 2486),
#  ('VB', 2440),
#  ('VBN', 2269),
#  ('RB', 2166),
#  ('CD', 2020),
#  ('CS', 1509),
#  ('VBG', 1398),
#  ('TO', 1237),
#  ('PPS', 1056),
#  ('PP$', 1051),
#  ('MD', 1031),
#  ('AP', 923),
#  ('NP-TL', 741),
#  ('``', 732),
#  ('BEZ', 730),
#  ('BEDZ', 716),
#  ("''", 702),
#  ('JJ-TL', 689),
#  ('PPSS', 602),
#  ('DT', 589),
#  ('BE', 525),
#  ('VBZ', 519),
#  ('NR', 495),
#  ('RP', 482),
#  ('QL', 468),
#  ('PPO', 412),
#  ('WPS', 395),
#  ('NNS-TL', 344),
#  ('WDT', 343),
#  ('BER', 328),
#  ('WRB', 328),
#  ('OD', 309),
#  ('HVZ', 301),
#  ('--', 300),
#  ('NP$', 279),
#  ('HV', 265),
#  ('HVD', 262),
#  ('*', 256),
#  ('BED', 252),
#  ('NPS', 215),
#  ('BEN', 212),
#  ('NN$', 210),
#  ('DTI', 205),
#  ('NP-HL', 186),
#  ('ABN', 183),
#  ('NN-HL', 171),
#  ('IN-TL', 164),
#  ('EX', 161),
#  (')', 151),
#  ('(', 148),
#  ('JJR', 145),
#  (':', 137),
#  ('DTS', 136),
#  ('JJT', 100),
#  ('CD-TL', 96),
#  ('NNS-HL', 92),
#  ('PN', 89),
#  ('RBR', 88),
#  ('VBN-TL', 87),
#  ('ABX', 73),
#  ('NN$-TL', 69),
#  ('IN-HL', 65),
#  ('DOD', 64),
#  ('DO', 63),
#  ('BEG', 57),
#  (',-HL', 55),
#  ('VBN-HL', 53),
#  ('NNS$', 50),
#  ('AT-TL', 50),
#  ('CD-HL', 50),
#  ('JJS', 49),
#  ('CC-TL', 46),
#  ("'", 46),
#  ('JJ-HL', 46),
#  ('MD*', 43),
#  ('VBZ-HL', 39),
#  ('PPL', 36),
#  ('PPS+BEZ', 31),
#  ('PPSS+MD', 31),
#  ('OD-TL', 30),
#  ('DOZ', 26),
#  ('VB-HL', 25),
#  ('NR$', 24),
#  ('FW-NN', 22),
#  ('WP$', 22),
#  ('PPLS', 21),
#  ('ABL', 21),
#  ('NNS$-TL', 20),
#  ('PPSS+BER', 20),
#  ('.-HL', 20),
#  ('(-HL', 20),
#  (')-HL', 20),
#  ('PPSS+HV', 19),
#  ('PPSS+BEM', 18),
#  ('HVN', 18),
#  ('DO*', 17),
#  ('NPS$', 17),
#  ('FW-NN-TL', 16),
#  ('NPS-TL', 15),
#  ('VBG-TL', 15),
#  ('DOD*', 15),
#  ('RB-HL', 15),
#  ('AT-HL', 14),
#  ('FW-IN', 14),
#  ('HVG', 14),
#  ('NR-TL', 14),
#  ('BEM', 13),
#  ('DOZ*', 13),
#  ('QLP', 12),
#  (':-HL', 12),
#  ('UH', 12),
#  ('VBG-HL', 12),
#  ('FW-JJ-TL', 12),
#  ('NN-TL-HL', 12),
#  ('DT+BEZ', 12),
#  ('NP$-TL', 11),
#  ('WPO', 9),
#  ('BEZ*', 8),
#  ('RB-TL', 8),
#  ('DTX', 8),
#  ('VB-TL', 8),
#  ('PPS+MD', 8),
#  ('AP-HL', 7),
#  ('CC-HL', 7),
#  ('TO-HL', 6),
#  ('FW-AT-TL', 6),
#  ('VBD-HL', 6),
#  ('RBT', 5),
#  ('MD-HL', 5),
#  ('BER*', 4),
#  ('JJR-TL', 4),
#  ('PPS+HVZ', 4),
#  ('RP-HL', 4),
#  ('JJR-HL', 4),
#  ('NN-NC', 3),
#  ('BEDZ*', 3),
#  ('FW-JJ', 3),
#  ('NPS-HL', 3),
#  ('FW-AT', 3),
#  ('BEZ-HL', 3),
#  ('PP$$', 3),
#  ('JJS-TL', 2),
#  ('CD$', 2),
#  ('FW-IN+NN', 2),
#  ('FW-NNS', 2),
#  ('NNS$-HL', 2),
#  ('HVD*', 2),
#  ('NR-HL', 2),
#  ('WPS+BEZ', 2),
#  ('NN$-HL', 2),
#  ('DTI-HL', 2),
#  ('EX+BEZ', 2),
#  ('JJT-HL', 2),
#  ('FW-*', 1),
#  ('BER-TL', 1),
#  ('NR$-TL', 1),
#  ('MD-TL', 1),
#  ('*-HL', 1),
#  ('NPS$-TL', 1),
#  ('OD-HL', 1),
#  ('JJ-NC', 1),
#  ('FW-DT', 1),
#  ('RB+BEZ', 1),
#  ('BE-HL', 1),
#  ('PN-HL', 1),
#  ('WQL', 1),
#  ('NP+BEZ', 1),
#  ('DT-HL', 1),
#  ('HVZ*', 1),
#  ('PPSS+HVD', 1),
#  ('FW-IN-TL', 1),
#  ('BED*', 1),
#  ('AP-TL', 1),
#  ('PPS+BEZ-HL', 1),
#  ('MD+HV', 1),
#  ('TO-TL', 1),
#  ('UH-TL', 1),
#  ('BEDZ-HL', 1),
#  ('RB$', 1),
#  ('FW-PP$-NC', 1),
#  ('QL-TL', 1),
#  ('PN+HVZ', 1),
#  ('PP$-TL', 1),
#  ('HVD-HL', 1),
#  ('VB+PPO', 1),
#  ('NNS-TL-HL', 1),
#  ('NP-TL-HL', 1),
#  ('FW-VB-NC', 1),
#  ('PPSS-HL', 1),
#  ('ABN-HL', 1),
#  ('VBN-TL-HL', 1),
#  ('FW-WDT', 1),
#  ('FW-CD', 1),
#  ('FW-IN+AT-TL', 1),
#  ('PN$', 1),
#  ('VBD-TL', 1),
#  ('AP$', 1),
#  ('MD*-HL', 1),
#  ('BER-HL', 1),
#  ('DO-HL', 1),
#  ('JJR-NC', 1),
#  ('FW-VB', 1),
#  ('FW-AT-HL', 1),
#  ('WDT+BEZ', 1),
#  ('DT$', 1),
#  ('CS-HL', 1),
#  ('FW-IN+NN-TL', 1),
#  ('FW-CC', 1)]

# %% [markdown]
# So what do these tags mean?

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %% [markdown]
# We can also find out what the most common nouns are. For the linguists, there are naturally many subgroups of nouns, let's see what we can get:

# %%
# frequency 
def find_tags(tag_prefix, tagged_text):
    cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text
                                  if tag.startswith(tag_prefix))
    return dict((tag, cfd[tag].most_common(5)) for tag in cfd.conditions()) #cfd.conditions() yields all tags possibilites

tagdict = find_tags('NN', brown_news_tagged)
#NN, rest are sub categories

for tag in sorted(tagdict):
    print(tag, tagdict[tag])
# Out:
# NN [('year', 137), ('time', 97), ('state', 88), ('week', 85), ('man', 72)]
# NN$ [("year's", 13), ("world's", 8), ("state's", 7), ("company's", 6), ("nation's", 6)]
# NN$-HL [("Navy's", 1), ("Golf's", 1)]
# NN$-TL [("President's", 11), ("Army's", 3), ("League's", 3), ("University's", 3), ("Gallery's", 3)]
# NN-HL [('sp.', 2), ('party', 2), ('condition', 2), ('war', 2), ('Question', 2)]
# NN-NC [('aya', 1), ('eva', 1), ('ova', 1)]
# NN-TL [('President', 88), ('House', 68), ('State', 59), ('University', 42), ('City', 41)]
# NN-TL-HL [('Fort', 2), ('Beat', 1), ('Dr.', 1), ('Street', 1), ('Grove', 1)]
# NNS [('years', 101), ('members', 69), ('people', 52), ('sales', 51), ('men', 46)]
# NNS$ [("children's", 7), ("women's", 5), ("men's", 3), ("janitors'", 3), ("builders'", 2)]
# NNS$-HL [("Dealers'", 1), ("Idols'", 1)]
# NNS$-TL [("Women's", 4), ("States'", 3), ("Giants'", 2), ("Braves'", 1), ("Raiders'", 1)]
# NNS-HL [('returns', 1), ('$37', 1), ('schools', 1), ('Charges', 1), ('places', 1)]
# NNS-TL [('States', 38), ('Nations', 11), ('Masters', 10), ('Bears', 9), ('Giants', 9)]
# NNS-TL-HL [('Nations', 1)]

# %% [markdown]
# We can also look at what linguistic environment words are in, below lists all the words following "President":

# %%
brown_news_text = brown.words(categories='news')
sorted(set(b for (a, b) in nltk.bigrams(brown_news_text) if a == 'President'))
# Out:
# ['(',
#  ',',
#  '.',
#  'Chen',
#  'Dwight',
#  'Eisenhower',
#  "Eisenhower's",
#  'Habib',
#  'John',
#  'Judge',
#  'Kasavubu',
#  'Kennedy',
#  "Kennedy's",
#  'Raymond',
#  'Richard',
#  'Sukarno',
#  'also',
#  'and',
#  'announced',
#  'asks',
#  'called',
#  'clearly',
#  'commented',
#  'had',
#  'has',
#  'held',
#  'himself',
#  'in',
#  'is',
#  'knew',
#  'left',
#  'noted',
#  'of',
#  'received',
#  'recommended',
#  'remarked',
#  'said',
#  'spent',
#  'sponsored',
#  'talked',
#  'to',
#  'took',
#  'was',
#  'which',
#  'will',
#  'would']

# %% [markdown]
# If we are looking to build a classifier, perhaps for author identification, it may be useful to quantify the syntax.

# %%
# bigrams - every single set of two words
# ngrams
# pos is 1 
# starts with Verb(VB)

tags = [b[1] for (a, b) in nltk.bigrams(brown_news_tagged) if a[1].startswith('VB')]
fd1 = nltk.FreqDist(tags)
fd1.tabulate(10)
# Out:
#   IN   AT   NN  NNS   TO   RP   CS    .   RB    ,
# 1888 1540  600  468  414  369  368  339  339  317

# %% [markdown]
# ## Automatic Tagging

# %% [markdown]
# Now that we know some things we can do with a tagged corpus, how can we tag our own corpus? We will work through regex models, n-gram models, and discuss a couple more advanced models.

# %% [markdown]
# ### Regex Tagger

# %% [markdown]
# Let's write a simple regex tagger for 8 parts of speech. First we need to define the patterns for each part:

# %%
# building a regex POS tagger
patterns = [
     (r'.*ing$', 'VBG'),               # gerunds, ending in 'ing'
     (r'.*ed$', 'VBD'),                # simple past , ending in 'ed' past tense
     (r'.*\'s$', 'NN$'),               # possessive nouns, ending in 's possesive 
     (r'.*s$', 'NNS'),                 # plural nouns - ending in s is plural
     (r'.*', 'NN')                     # nouns (default) - 
 ]

# %%
gsents
# Out:
# [['My', 'father', 'had', 'a', 'small', 'estate', 'in', 'Nottinghamshire', ';', 'I', 'was', 'the', 'third', 'of', 'five', 'sons', '.'], ['He', 'sent', 'me', 'to', 'Emmanuel', 'College', 'in', 'Cambridge', 'at', 'fourteen', 'years', 'old', ',', 'where', 'I', 'resided', 'three', 'years', ',', 'and', 'applied', 'myself', 'close', 'to', 'my', 'studies', ';', 'but', 'the', 'charge', 'of', 'maintaining', 'me', ',', 'although', 'I', 'had', 'a', 'very', 'scanty', 'allowance', ',', 'being', 'too', 'great', 'for', 'a', 'narrow', 'fortune', ',', 'I', 'was', 'bound', 'apprentice', 'to', 'Mr', '.', 'James', 'Bates', ',', 'an', 'eminent', 'surgeon', 'in', 'London', ',', 'with', 'whom', 'I', 'continued', 'four', 'years', ';', 'and', 'my', 'father', 'now', 'and', 'then', 'sending', 'me', 'small', 'sums', 'of', 'money', ',', 'I', 'laid', 'them', 'out', 'in', 'learning', 'navigation', ',', 'and', 'other', 'parts', 'of', 'the', 'mathematics', 'useful', 'to', 'those', 'who', 'intend', 'to', 'travel', ',', 'as', 'I', 'always', 'believed', 'it', 'would', 'be', ',', 'some', 'time', 'or', 'other', ',', 'my', 'fortune', 'to', 'do', '.'], ...]

# %% [markdown]
# Now we build the tagger and we can test it on the first sentence of our *Gulliver's Travels*.

# %%
regexp_tagger = nltk.RegexpTagger(patterns)
regexp_tagger.tag(gsents[0])
#99% accuracy
# Out:
# [('My', 'NN'),
#  ('father', 'NN'),
#  ('had', 'NN'),
#  ('a', 'NN'),
#  ('small', 'NN'),
#  ('estate', 'NN'),
#  ('in', 'NN'),
#  ('Nottinghamshire', 'NN'),
#  (';', 'NN'),
#  ('I', 'NN'),
#  ('was', 'NNS'),
#  ('the', 'NN'),
#  ('third', 'NN'),
#  ('of', 'NN'),
#  ('five', 'NN'),
#  ('sons', 'NNS'),
#  ('.', 'NN')]

# %% [markdown]
# That didn't work so well, no worries, this was a very naïve attempt. But we can evaluate the accuracy nonetheless:

# %%
brown_tagged_sents = brown.tagged_sents(categories='news')
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.19909700260556518

# %% [markdown]
# ### N-Gram Tagging

# %% [markdown]
# N-Gram tagging is a very basic supervised machine learning technique. It looks at a word and *n* previous words' tags to determine the best tag for the focal word. Because n-gram tagging and other machine learning models require data to train on they are called "supervised", because you know the data being given to it. This also means that we must divide the data into training and testing data, because if you test your model on the same data it was trained with, you will have a great degree of bias. Originally, a 90-10 divide was recommended, but standards have now changed to k-fold cross-validation, usually 10 folds.

# %%
#divide tagged data
size = int(len(brown_tagged_sents) * 0.9)
train_sents = brown_tagged_sents[:size]
test_sents = brown_tagged_sents[size:]

#train bigram tagger
bigram_tagger = nltk.BigramTagger(train_sents) #word and tag of prev word

# %% [markdown]
# We can now try this tagger on that sentence again:

# %%
bigram_tagger.tag(gsents[0])
# Out:
# [('My', 'PP$'),
#  ('father', 'NN'),
#  ('had', 'HVD'),
#  ('a', 'AT'),
#  ('small', 'JJ'),
#  ('estate', 'NN'),
#  ('in', 'IN'),
#  ('Nottinghamshire', None),
#  (';', None),
#  ('I', None),
#  ('was', None),
#  ('the', None),
#  ('third', None),
#  ('of', None),
#  ('five', None),
#  ('sons', None),
#  ('.', None)]

# %% [markdown]
# All of the "None" means it didn't know how to tag it because the model was insufficient, as once it encounters an unknown word to tag, the following will also be un-taggable. To fix this we have to implement backoff tagging, or cascading taggers:

# %%
t0 = nltk.RegexpTagger(patterns)
t1 = nltk.UnigramTagger(train_sents, backoff=t0) #only current word, most likely tag
t2 = nltk.BigramTagger(train_sents, backoff=t1)
t3 = nltk.TrigramTagger(train_sents, backoff=t2)

# %% [markdown]
# Now let's try to tag that sentence again:

# %%
t3.tag(gsents[0])
# Out:
# [('My', 'PP$'),
#  ('father', 'NN'),
#  ('had', 'HVD'),
#  ('a', 'AT'),
#  ('small', 'JJ'),
#  ('estate', 'NN'),
#  ('in', 'IN'),
#  ('Nottinghamshire', 'NN'),
#  (';', '.'),
#  ('I', 'PPSS'),
#  ('was', 'BEDZ'),
#  ('the', 'AT'),
#  ('third', 'OD'),
#  ('of', 'IN'),
#  ('five', 'CD'),
#  ('sons', 'NNS'),
#  ('.', '.')]

# %%
t3.evaluate(test_sents)
# Out:
# 0.8674374563939001

# %% [markdown]
# ### Transformation-based Brill Tagging

# %% [markdown]
# There are many different machine learning algorithms out there. The current "hot" choice is neural networks, but that is beyond the scope of this workshop. Let's look at a transformation-based tagger included in NLTK, which will help us understand how many machine learning models make decisions.

# %%
from nltk.tag.brill import *

def train_brill_tagger(tagged_sents):
    t0 = nltk.RegexpTagger(patterns)
    t1 = nltk.UnigramTagger(train_sents, backoff=t0)
    t2 = nltk.BigramTagger(train_sents, backoff=t1)
    t3 = nltk.TrigramTagger(train_sents, backoff=t2)
    Template._cleartemplates()
    templates = brill24() #or fntbl37
    t4 = nltk.tag.brill_trainer.BrillTaggerTrainer(t3, templates, trace=3)
    t4 = t4.train(tagged_sents, max_rules=100)
    
    return t4

tagger = train_brill_tagger(brown_tagged_sents)
# Out:
# TBL train (fast) (seqs: 4623; tokens: 100554; tpls: 24; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 47380 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#  216 221   5   0  | IN->TO if Pos:VB@[1]
#  114 114   0   1  | TO->IN if Pos:AT@[1]
#   36  37   1   0  | CS->QL if Word:as@[2]
#   30  30   0   1  | TO->IN if Pos:NP@[1]
#   22  22   0   0  | IN->TO if Word:to@[0] & Word:be@[1] & Pos:BE@[1]
#   20  20   0   0  | NNS->NPS if Word:Belgians@[-1,0]
#   19  19   0   0  | TO->IN if Pos:NNS@[1]
#   17  58  41   6  | NN->VB if Word:to@[-1] & Pos:IN@[-1]
#   18  18   0   0  | IN->TO if Pos:VB@[1] & Pos:AT@[2]
#   14  14   0   0  | NN->NP if Word:Lumumba@[0,1]
#   13  13   0   0  | CS->WPS if Pos:VBD@[1]
#   12  12   0   0  | TO->IN if Pos:PP$@[1]
#   11  11   0   0  | TO->IN if Pos:CD@[1]
#   10  11   1   0  | VBD->VBN if Pos:HVD@[-2,-1]
#    9   9   0   0  | VBD->VBN if Pos:HV@[-3,-2,-1]
#    9  15   6   0  | IN->TO if Pos:VB@[1] & Pos:IN@[2]
#   10  35  25   6  | VB->NN if Pos:IN@[-1]
#    9   9   0   0  | NNS->NP if Word:Holmes@[-1,0]
#    8   8   0   0  | IN->TO if Pos:DO@[1]
#    8  11   3   0  | TO->IN if Pos:JJ@[1]
#    8   8   0   0  | WPS->CS if Pos:AT@[1]
#    8   8   0   0  | CS->DT if Pos:VB@[-1] & Pos:NN@[1]
#    8   8   0   0  | NN->NP if Word:Tshombe@[0,1]
#    7   7   0   4  | VBD->VBN if Pos:AT@[-1]
#    7   7   0   2  | CS->WPS if Pos:VBZ@[1]
#    7  27  20   0  | TO->IN if Pos:NN@[1]
#    7   7   0   0  | TO->IN if Pos:NN-TL@[1]
#    7   7   0   1  | NN->JJ if Word:Belgian@[0,1]
#    6   6   0   0  | NN->VB if Pos:MD@[-1]
#    6   6   0   0  | VBD->VBN if Pos:HVZ@[-1]
#    6   6   0   0  | VBN->VBD if Pos:PPSS@[-1]
#    6  10   4   0  | CS->WPS if Pos:MD@[1]
#    6   6   0   0  | IN->CS if Pos:PPS@[1]
#    6   6   0   0  | TO->IN if Pos:CS@[1]
#    6   6   0   0  | TO->IN if Pos:PPO@[1]
#    6   6   0   0  | VBD->VBN if Pos:BER@[-2,-1]
#    6   7   1   0  | TO->IN if Pos:NP-TL@[1,2]
#    6   6   0   1  | CS->WPS if Pos:NNS@[-1] & Pos:VB@[1]
#    6   7   1   0  | IN->RP if Pos:VBD@[-1] & Pos:IN@[1]
#    6   6   0   2  | IN->RP if Word:bring@[-1]
#    6   8   2   0  | NP->NP-TL if Word:State@[1]
#    6   6   0   0  | NN->CD if Word:cent@[2]
#    6   6   0   0  | NN->NN-TL if Word:Turnpike@[-1,0]
#    6   6   0   0  | JJ->ABL if Word:such@[0] & Word:a@[1] & Pos:AT@[1]
#    5   7   2   0  | VB->NN if Pos:JJ@[-1]
#    5   5   0   0  | VBD->VBN if Pos:BEDZ@[-1]
#    5   6   1   0  | JJS->NN if Pos:IN@[1]
#    5   5   0   0  | TO->IN if Pos:VBG@[1]
#    5   5   0   0  | CS->DT if Pos:''@[1,2]
#    5   5   0   1  | NP-HL->NP if Pos:VBD@[1,2,3]
#    5  14   9   1  | NP->NP-TL if Pos:AT@[-1] & Pos:NN-TL@[1]
#    5   5   0   0  | NN->NP if Word:Kasavubu@[-1,0]
#    5   5   0   0  | NN->NP if Word:Katanga@[-1,0]
#    5   5   0   0  | NNS->NPS if Word:Beardens@[-1,0]
#    4   4   0   0  | VBD->VBN if Pos:BEZ@[-1]
#    4   4   0   0  | VBN->VBD if Pos:WPS@[-1]
#    4   4   0   0  | CS->WPS if Pos:BEZ@[1]
#    4   4   0   0  | WPS->CS if Pos:PPS@[1]
#    4   4   0   0  | VBD->VBN if Pos:BE@[-2,-1]
#    4   5   1   0  | CS->IN if Pos:CD@[1] & Pos:.@[2]
#    4   4   0   0  | IN->TO if Pos:``@[1] & Pos:VB@[2]
#    4   5   1   0  | VBN->VBD if Word:that@[-1]
#    4   4   0   0  | CS->WPS if Pos:NN@[-1] & Pos:VBD@[1]
#    4   4   0   0  | NN->NP if Word:Bearden@[-1,0]
#    4   4   0   0  | NN->NP if Word:Charlayne@[-1,0]
#    4   4   0   0  | NN->NP if Word:Chen@[-1,0]
#    4   4   0   0  | NN->NP if Word:Crosby@[-1,0]
#    4   4   0   0  | NN->NP if Word:Kimpton@[-1,0]
#    4   4   0   0  | NNS->NP if Word:Rickards@[-1,0]
#    4   4   0   8  | NN->JJ if Word:Congolese@[0,1]
#    4   4   0   0  | NN->NP if Word:Fiat@[0,1]
#    4   4   0   3  | NN->NP if Word:Nassau@[0,1]
#    5   6   1   0  | NP->NP-TL if Word:County@[1]
#    4   4   0   0  | NN->NP if Word:Olivetti@[0,1]
#    4   4   0   0  | IN->RP if Word:on@[0] & Word:to@[1] & Pos:TO@[1]
#    4   6   2   0  | RP->IN if Word:on@[0] & Word:the@[1] & Pos:AT@[1]
#    3   3   0   0  | NNS->VBZ if Pos:PPS@[-1]
#    3   3   0   1  | VB->NN if Pos:AT@[-1]
#    3   3   0   0  | VBD->VBN if Pos:BED@[-1]
#    3   4   1   0  | VBN->VBD if Pos:WDT@[-1]
#    3   3   0   0  | AT-TL->AT if Pos:NN@[1]
#    3   3   0   1  | CS->WPS if Pos:HVD@[1]
#    3   3   0   0  | CS->WPS if Pos:HVZ@[1]
#    3   3   0   0  | NR-TL->JJ-TL if Pos:NN-TL@[1]
#    3   3   0   0  | RBR->QL if Pos:JJ@[1]
#    3   3   0   0  | TO->IN if Pos:AP@[1]
#    3   3   0   0  | TO->IN if Pos:IN@[1]
#    3   3   0   0  | TO->IN if Pos:JJR@[1]
#    3   3   0   0  | TO->IN if Pos:NP$@[1]
#    3   3   0   0  | TO->IN if Pos:PN@[1]
#    3   3   0   0  | VBZ-HL->VBZ if Pos:NN@[-2,-1]
#    3   4   1   0  | AT-TL->AT if Pos:NP@[1,2]
#    4   5   1   0  | IN-TL->IN if Pos:AT@[1]
#    3   3   0   0  | IN-TL->IN if Pos:CD@[1,2]
#    3   3   0   0  | EX->RB if Pos:PP$@[1,2,3]
#    3  10   7   2  | JJ->NN if Pos:AT@[-1] & Pos:IN@[1]
#    3   3   0   0  | NN->NN-TL if Pos:NN-TL@[-1] & Pos:NN-TL@[1]
#    3   3   0   1  | NN->RB if Pos:,@[-1] & Pos:VBD@[1]
#    3   4   1   0  | NP-TL->NP if Pos:AT@[-1] & Pos:NN@[1]
#    3   3   0   0  | VBN->VBD if Pos:NN@[-1] & Pos:NN@[1]

# %% [markdown]
# We see that the Brill tagger corrects itself up to a certain threshold based on rules it generated from the data we gave it. Other machine learning models such as Conditional Random Fields (CRF) work in a similar way, in that you tell it what features are important to look at, and it weights these features in writing its rules. Neural networks go more into linear algebra and matrix multiplication, a different approach. Libraries do exist for easy implmentation of neural nets such as pybrain (http://pybrain.org) for general advanced modelling, and nlpnet (http://nilc.icmc.usp.br/nlpnet/index.html) for POS or SRL (Semantic Role Labeling).
#
# So let's tag that sentence again with our Brill tagger:

# %%
gtagged_sent = tagger.tag(gsents[0])
print (gtagged_sent)
# Out:
# [('My', 'PP$'), ('father', 'NN'), ('had', 'HVD'), ('a', 'AT'), ('small', 'JJ'), ('estate', 'NN'), ('in', 'IN'), ('Nottinghamshire', 'NN'), (';', '.'), ('I', 'PPSS'), ('was', 'BEDZ'), ('the', 'AT'), ('third', 'OD'), ('of', 'IN'), ('five', 'CD'), ('sons', 'NNS'), ('.', '.')]

# %%
tagger.evaluate(test_sents)
# Out:
# 0.9002292434964617

# %% [markdown]
# Let's POS tag our entire text:

# %%
#list comprehension
g_tagged_all = [tagger.tag(sent) for sent in gsents]

# %%
g_tagged_all[:3]
# Out:
# [[('My', 'PP$'),
#   ('father', 'NN'),
#   ('had', 'HVD'),
#   ('a', 'AT'),
#   ('small', 'JJ'),
#   ('estate', 'NN'),
#   ('in', 'IN'),
#   ('Nottinghamshire', 'NN'),
#   (';', '.'),
#   ('I', 'PPSS'),
#   ('was', 'BEDZ'),
#   ('the', 'AT'),
#   ('third', 'OD'),
#   ('of', 'IN'),
#   ('five', 'CD'),
#   ('sons', 'NNS'),
#   ('.', '.')],
#  [('He', 'PPS'),
#   ('sent', 'VBD'),
#   ('me', 'PPO'),
#   ('to', 'IN'),
#   ('Emmanuel', 'NN'),
#   ('College', 'NN-TL'),
#   ('in', 'IN'),
#   ('Cambridge', 'NP'),
#   ('at', 'IN'),
#   ('fourteen', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('where', 'WRB'),
#   ('I', 'PPSS'),
#   ('resided', 'VBD'),
#   ('three', 'CD'),
#   ('years', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('applied', 'VBD'),
#   ('myself', 'PPL'),
#   ('close', 'JJ'),
#   ('to', 'IN'),
#   ('my', 'PP$'),
#   ('studies', 'NNS'),
#   (';', '.'),
#   ('but', 'CC'),
#   ('the', 'AT'),
#   ('charge', 'NN'),
#   ('of', 'IN'),
#   ('maintaining', 'VBG'),
#   ('me', 'PPO'),
#   (',', ','),
#   ('although', 'CS'),
#   ('I', 'PPSS'),
#   ('had', 'HVD'),
#   ('a', 'AT'),
#   ('very', 'QL'),
#   ('scanty', 'NN'),
#   ('allowance', 'NN'),
#   (',', ','),
#   ('being', 'BEG'),
#   ('too', 'QL'),
#   ('great', 'JJ'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('narrow', 'JJ'),
#   ('fortune', 'NN'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('was', 'BEDZ'),
#   ('bound', 'VBN'),
#   ('apprentice', 'NN'),
#   ('to', 'IN'),
#   ('Mr', 'NN'),
#   ('.', '.'),
#   ('James', 'NP'),
#   ('Bates', 'NNS'),
#   (',', ','),
#   ('an', 'AT'),
#   ('eminent', 'JJ'),
#   ('surgeon', 'NN'),
#   ('in', 'IN'),
#   ('London', 'NP'),
#   (',', ','),
#   ('with', 'IN'),
#   ('whom', 'WPO'),
#   ('I', 'PPSS'),
#   ('continued', 'VBD'),
#   ('four', 'CD'),
#   ('years', 'NNS'),
#   (';', '.'),
#   ('and', 'CC'),
#   ('my', 'PP$'),
#   ('father', 'NN'),
#   ('now', 'RB'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('sending', 'VBG'),
#   ('me', 'PPO'),
#   ('small', 'JJ'),
#   ('sums', 'NNS'),
#   ('of', 'IN'),
#   ('money', 'NN'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('laid', 'VBD'),
#   ('them', 'PPO'),
#   ('out', 'RP'),
#   ('in', 'IN'),
#   ('learning', 'VBG'),
#   ('navigation', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('other', 'AP'),
#   ('parts', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('mathematics', 'NN'),
#   ('useful', 'JJ'),
#   ('to', 'TO'),
#   ('those', 'DTS'),
#   ('who', 'WPS'),
#   ('intend', 'VB'),
#   ('to', 'IN'),
#   ('travel', 'NN'),
#   (',', ','),
#   ('as', 'CS'),
#   ('I', 'PPSS'),
#   ('always', 'RB'),
#   ('believed', 'VBN'),
#   ('it', 'PPO'),
#   ('would', 'MD'),
#   ('be', 'BE'),
#   (',', ','),
#   ('some', 'DTI'),
#   ('time', 'NN'),
#   ('or', 'CC'),
#   ('other', 'AP'),
#   (',', ','),
#   ('my', 'PP$'),
#   ('fortune', 'NN'),
#   ('to', 'TO'),
#   ('do', 'DO'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('I', 'PPSS'),
#   ('left', 'VBD'),
#   ('Mr', 'NN'),
#   ('.', '.'),
#   ('Bates', 'NNS'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('went', 'VBD'),
#   ('down', 'RP'),
#   ('to', 'IN'),
#   ('my', 'PP$'),
#   ('father', 'NN'),
#   (',', ','),
#   ('where', 'WRB'),
#   (',', ','),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('assistance', 'NN'),
#   ('of', 'IN'),
#   ('him', 'PPO'),
#   (',', ','),
#   ('and', 'CC'),
#   ('my', 'PP$'),
#   ('uncle', 'NN'),
#   ('John', 'NP'),
#   ('and', 'CC'),
#   ('some', 'DTI'),
#   ('other', 'AP'),
#   ('relations', 'NNS'),
#   (',', ','),
#   ('I', 'PPSS'),
#   ('got', 'VBD'),
#   ('forty', 'NN'),
#   ('pounds', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('a', 'AT'),
#   ('promise', 'NN'),
#   ('of', 'IN'),
#   ('thirty', 'NN'),
#   ('pounds', 'NNS'),
#   ('a', 'AT'),
#   ('year', 'NN'),
#   (',', ','),
#   ('to', 'TO'),
#   ('maintain', 'VB'),
#   ('me', 'PPO'),
#   ('at', 'IN'),
#   ('Leyden', 'NN'),
#   ('.', '.')]]

# %% [markdown]
# What types of adjectives are used?

# %%
# flattens the list
g_tagged_words = [item for sublist in g_tagged_all for item in sublist]

tagdict = find_tags('JJ', g_tagged_words)
for tag in sorted(tagdict):
    print(tag, tagdict[tag])
# Out:
# JJ [('great', 132), ('own', 73), ('good', 61), ('long', 47), ('whole', 39)]
# JJ-TL [('Big', 6), ('South', 2), ('Old', 2), ('East', 2), ('Good', 2)]
# JJR [('larger', 15), ('better', 14), ('smaller', 14), ('greater', 10), ('lower', 3)]
# JJS [('principal', 12), ('chief', 9), ('top', 2), ('main', 1)]
# JJT [('greatest', 16), ('largest', 15), ('strongest', 10), ('best', 10), ('highest', 7)]

# %% [markdown]
# How about we compare the syntax of Gulliver's Travels to the news corpus:

# %%
#pos tags which follows verbs
tags = [b[1] for (a, b) in nltk.bigrams(g_tagged_words) if a[1].startswith('VB')]
fd2 = nltk.FreqDist(tags)

print ("Gulliver")
fd2.tabulate(10)
#PPO Personal Pronoun
print ()
print ("News")
fd1.tabulate(10)
# Out:
# Gulliver
#   IN  PPO   AT    ,  PP$   RP   NN   TO    .   RB
# 1258  702  563  389  292  231  220  207  171  119
#
# News
#   IN   AT   NN  NNS   TO   RP   CS    .   RB    ,
# 1888 1540  600  468  414  369  368  339  339  317

# %% [markdown]
# There are several explanations for the difference. Perhaps due to the familiarity with characters in the novel form, personal pronoun objects ("me, him, her, etc.") are more common to follow verbs than articles, which likely attempt to clarify an unknown in a news source.

# %% [markdown]
# In developing machine learning models, you may want to know where the model is making errors. This can be done by examining the Confusion Matrix:

# %%
def tag_list(tagged_sents):
    return [tag for sent in tagged_sents for (word, tag) in sent] #just grabbing a list of all the tags
def apply_tagger(tagger, corpus):
    return [tagger.tag(nltk.tag.untag(sent)) for sent in corpus] #notice we first untag the sentence

gold = tag_list(brown_tagged_sents)
test = tag_list(apply_tagger(tagger, brown_tagged_sents))

cm = nltk.ConfusionMatrix(gold, test)
print(cm.pretty_format(sort_by_count=True, show_percents=True, truncate=10))

# %% [markdown]
# ### Pickling

# %% [markdown]
# If you want to save your model, or any complex variable in Python, you can use pickle:

# %%
from pickle import dump,load

with open("brilltagger.pkl", "wb") as f:
    dump (tagger, f, -1) #-1 calls for a more efficient binary protocol

# %%
with open('brilltagger.pkl', 'rb') as f:
    tagger = load(f)
    
type (tagger)

# %% [markdown]
# ## 3) Chunking, grammars, and Named Entity Recognition

# %% [markdown]
# On a low linguistic level, you may want to map out a sentence visually based on parts of speech, of course this visualization is actually just a navigable data type, which can be used to mine statistics. We have to first define the grammar. We'll just define a noun phrase for English consisting of a determiner, indefinite article, count, or possessive pronoun, an adjective, and noun. Defining the grammar is done similarly to writing regular expressions. We can then draw the map.

# %%
grammar = r"""
  NP: {<DT|AT|CD|PP\$>?<JJ>*<PPSS|NN.*>}       
  PP: {<IN><NP>}            
  VP: {<BEDZ|HVD|VB.*><AT>?<OD>?<NP|PP|CLAUSE>+} 
  CLAUSE: {<NP><VP>}        
  """
# | is "or", a following ? means optional, * is 0 or more, .* is anything following

cp = nltk.RegexpParser(grammar)
result = cp.parse(gtagged_sent)
result #result.draw() for not in python notebook

# %%
print (result) #can be traversed using indexes, obviously searched as well

# %% [markdown]
# With this information, we can then train classifiers for Named Entity Recognition (NER), i.e. identifying people, places, and things. We won't go into detail today, but NLTK already has a trained classfier we can use off-the-shelf:

# %%
print (nltk.ne_chunk(gtagged_sent, binary=True))

# %% [markdown]
# ## 4) Document Classification

# %% [markdown]
# We now download a corpus of movie reviews, which were already labeled as positive or negative. We can build a Naive Bayes Classifier to learn from the annotated data and then predict unseen reviews as positive or negative.

# %%
import random
from nltk.corpus import movie_reviews

movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids()
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]

# %%
#
documents = [(list(movie_reviews.words(fileid)), category)
                for category in movie_reviews.categories()
                for fileid in movie_reviews.fileids(category)]
#shuffle to avoid bias
random.shuffle(documents)

# %%
#long ist of tuples
documents[0]
# Out:
# (['a',
#   'fully',
#   'loaded',
#   'entertainment',
#   'review',
#   '-',
#   'website',
#   'coming',
#   'in',
#   'july',
#   '!',
#   '>',
#   'from',
#   'ace',
#   'ventura',
#   'to',
#   'truman',
#   'burbank',
#   ',',
#   'jim',
#   'carrey',
#   'has',
#   'run',
#   'the',
#   'whole',
#   'gamut',
#   'of',
#   'comic',
#   ',',
#   'yet',
#   'sympathetic',
#   ',',
#   'characters',
#   '.',
#   '1996',
#   "'",
#   's',
#   'the',
#   'cable',
#   'guy',
#   'was',
#   'supposed',
#   'to',
#   'be',
#   'his',
#   'big',
#   '"',
#   'breakthrough',
#   '"',
#   'role',
#   'from',
#   'zany',
#   'humor',
#   'into',
#   'darker',
#   ',',
#   'more',
#   'dramatic',
#   'acting',
#   '.',
#   'as',
#   'most',
#   'everyone',
#   'knows',
#   ',',
#   'the',
#   'results',
#   'were',
#   ',',
#   'well',
#   ',',
#   'less',
#   '-',
#   'than',
#   '-',
#   'stellar',
#   '.',
#   'not',
#   'only',
#   'did',
#   'the',
#   'film',
#   'not',
#   'do',
#   'so',
#   'hot',
#   'at',
#   'the',
#   'box',
#   'office',
#   ',',
#   'but',
#   'it',
#   'was',
#   'also',
#   'panned',
#   'by',
#   'critics',
#   '.',
#   'as',
#   'far',
#   'as',
#   'i',
#   'know',
#   ',',
#   'gene',
#   'siskel',
#   'and',
#   'i',
#   'are',
#   'the',
#   'only',
#   'ones',
#   'willing',
#   'to',
#   'admit',
#   'that',
#   'we',
#   'dug',
#   'it',
#   '.',
#   'the',
#   'first',
#   'time',
#   'i',
#   'saw',
#   'the',
#   'cable',
#   'guy',
#   ',',
#   'in',
#   'theatres',
#   ',',
#   'i',
#   'was',
#   'in',
#   'super',
#   'critic',
#   '-',
#   'mode',
#   ',',
#   'and',
#   'didn',
#   "'",
#   't',
#   'really',
#   'like',
#   'it',
#   '.',
#   'however',
#   ',',
#   'due',
#   'to',
#   'the',
#   'fact',
#   'that',
#   'hbo',
#   'shows',
#   'the',
#   'movie',
#   'every',
#   'single',
#   'day',
#   ',',
#   'i',
#   "'",
#   've',
#   'had',
#   'time',
#   'to',
#   'lean',
#   'back',
#   ',',
#   'relax',
#   ',',
#   'and',
#   'take',
#   'in',
#   'the',
#   'film',
#   '.',
#   'and',
#   'to',
#   'my',
#   'surprise',
#   ',',
#   'it',
#   'grew',
#   'on',
#   'me',
#   '.',
#   'the',
#   'plot',
#   'is',
#   'rather',
#   'simple',
#   ':',
#   'broderick',
#   'plays',
#   'a',
#   'guy',
#   'named',
#   'steven',
#   'who',
#   'befriends',
#   'his',
#   'cable',
#   'guy',
#   ',',
#   'played',
#   'by',
#   'carrey',
#   ',',
#   'then',
#   'is',
#   'stalked',
#   'by',
#   'him',
#   'when',
#   'steven',
#   'tries',
#   'to',
#   'break',
#   'off',
#   'the',
#   'relationship',
#   '.',
#   'see',
#   ',',
#   'steven',
#   "'",
#   's',
#   'been',
#   'having',
#   'some',
#   'problems',
#   'with',
#   'his',
#   'girlfriend',
#   ',',
#   'robin',
#   '(',
#   'leslie',
#   'mann',
#   ')',
#   ',',
#   'and',
#   'he',
#   'doesn',
#   "'",
#   't',
#   'think',
#   'he',
#   'has',
#   'any',
#   'more',
#   'room',
#   'in',
#   'his',
#   'life',
#   'for',
#   'a',
#   'new',
#   'friend',
#   '.',
#   'also',
#   ',',
#   'some',
#   'of',
#   'the',
#   'cable',
#   'guy',
#   "'",
#   's',
#   'antics',
#   'have',
#   'been',
#   'creeping',
#   'him',
#   'out',
#   '.',
#   'carrey',
#   ',',
#   'as',
#   'the',
#   'cable',
#   'guy',
#   ',',
#   'gives',
#   'steven',
#   'various',
#   'aliases',
#   ',',
#   'which',
#   'later',
#   'we',
#   'find',
#   'out',
#   'are',
#   'all',
#   'tv',
#   'characters',
#   ':',
#   'larry',
#   'tate',
#   ',',
#   'chip',
#   'douglas',
#   ',',
#   'ricky',
#   'ricardo',
#   ',',
#   'etc',
#   '.',
#   'he',
#   'apparently',
#   'lives',
#   'in',
#   'his',
#   'cable',
#   'van',
#   ',',
#   'and',
#   'while',
#   'many',
#   'critics',
#   'didn',
#   "'",
#   't',
#   'enjoy',
#   'this',
#   'newer',
#   ',',
#   'darker',
#   ',',
#   'less',
#   '-',
#   'manic',
#   'performance',
#   'from',
#   'carrey',
#   ',',
#   'i',
#   'thought',
#   'it',
#   'was',
#   'interesting',
#   'and',
#   'rather',
#   'well',
#   '-',
#   'done',
#   '.',
#   'for',
#   'me',
#   ',',
#   'its',
#   'not',
#   'the',
#   'movie',
#   'as',
#   'a',
#   'whole',
#   'that',
#   "'",
#   's',
#   'enjoyable',
#   ',',
#   'but',
#   'rather',
#   'several',
#   'individual',
#   'scenes',
#   ':',
#   'a',
#   'karaoke',
#   'jam',
#   'at',
#   'steven',
#   "'",
#   's',
#   'apartment',
#   ',',
#   'a',
#   'medieval',
#   'fight',
#   'at',
#   'a',
#   'theme',
#   'restaurant',
#   ',',
#   'and',
#   'a',
#   'bathroom',
#   'beating',
#   '(',
#   'a',
#   'la',
#   'liar',
#   ',',
#   'liar',
#   ')',
#   ',',
#   'just',
#   'to',
#   'name',
#   'a',
#   'few',
#   '.',
#   'perhaps',
#   'the',
#   'fact',
#   'that',
#   'more',
#   'of',
#   'carrey',
#   "'",
#   's',
#   'humorous',
#   'side',
#   'comes',
#   'out',
#   'during',
#   'these',
#   'scenes',
#   'is',
#   'what',
#   'makes',
#   'them',
#   'so',
#   'funny',
#   '.',
#   'and',
#   'if',
#   'you',
#   'really',
#   'want',
#   'to',
#   'see',
#   'something',
#   ',',
#   'you',
#   "'",
#   've',
#   'got',
#   'to',
#   'hear',
#   'his',
#   'version',
#   'of',
#   'jefferson',
#   'airplane',
#   "'",
#   's',
#   '"',
#   'somebody',
#   'to',
#   'love',
#   '"',
#   ',',
#   'sung',
#   'at',
#   'the',
#   'aformentioned',
#   'karaoke',
#   'jam',
#   '.',
#   'the',
#   'cable',
#   'guy',
#   'has',
#   'its',
#   'bad',
#   'spots',
#   ',',
#   'like',
#   'most',
#   'any',
#   'movie',
#   '.',
#   'i',
#   'didn',
#   "'",
#   't',
#   'particularly',
#   'like',
#   'steven',
#   "'",
#   's',
#   'girlfriend',
#   ',',
#   'and',
#   'i',
#   'felt',
#   'that',
#   'more',
#   'focus',
#   'should',
#   'have',
#   'been',
#   'used',
#   'on',
#   'the',
#   'relationship',
#   'between',
#   'steven',
#   'and',
#   'his',
#   'best',
#   'friend',
#   '.',
#   'also',
#   ',',
#   'the',
#   'ending',
#   ',',
#   'while',
#   'having',
#   'you',
#   'fooled',
#   'for',
#   'a',
#   'moment',
#   ',',
#   'is',
#   'rather',
#   'contrived',
#   ',',
#   'and',
#   'somewhat',
#   'dissapointing',
#   '.',
#   'still',
#   ',',
#   'i',
#   'found',
#   'the',
#   'cable',
#   'guy',
#   'to',
#   'be',
#   'a',
#   'worthwhile',
#   'venture',
#   ';',
#   'if',
#   'you',
#   "'",
#   're',
#   'at',
#   'the',
#   'video',
#   'store',
#   'and',
#   'can',
#   "'",
#   't',
#   'think',
#   'of',
#   'anything',
#   'to',
#   'rent',
#   ',',
#   'i',
#   'suggest',
#   'you',
#   'try',
#   'it',
#   'out',
#   '.',
#   'or',
#   'if',
#   'you',
#   'have',
#   'hbo',
#   ',',
#   'just',
#   'wait',
#   'till',
#   'it',
#   'comes',
#   'on',
#   '(',
#   'you',
#   'won',
#   "'",
#   't',
#   'have',
#   'to',
#   'wait',
#   'long',
#   '.',
#   ')',
#   'hell',
#   ',',
#   'that',
#   "'",
#   's',
#   'what',
#   'i',
#   'do',
#   'every',
#   'day',
#   '.'],
#  'pos')

# %% [markdown]
# We will use a relatively simple model of only two features: single words and bigrams. First we need to get a list of the most common words and bigrams in the entire corpus.

# %%
# most freq positive words
# most freq negative words
movie_words = [w.lower() for w in movie_reviews.words()]
all_words = nltk.FreqDist(movie_words)
#most common 2000 words
word_features = list(all_words.most_common())[:2000]
word_features = [x[0] for x in word_features]

all_bis = nltk.bigrams(movie_words)
all_bis = nltk.FreqDist(all_bis)
bi_features = list(all_bis.most_common())[:2000]
bi_features = [x[0] for x in bi_features]
bi_features[:10]
# Out:
# [("'", 's'),
#  (',', 'and'),
#  ('of', 'the'),
#  ('.', 'the'),
#  ("'", 't'),
#  ('in', 'the'),
#  (',', 'but'),
#  (',', 'the'),
#  ('the', 'film'),
#  ('it', "'")]

# %% [markdown]
# Now we define features we deem relevant for classifying a document, in our case we will only use the words and bigrams generated above.

# %%
#tokenized words
def document_features(document):
    # set - gives unique
    document_words = set(document)
    document_bis = set(nltk.bigrams(document))
    #more features can be added
    #pos features can be added
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    for bi in bi_features:
        features['contains({})'.format(str(bi))] = (bi in document_bis)
    return features

# %% [markdown]
# We then extract all these features into a tuple with the classification. Divide into training and testing sets, and train the classfier.

# %%
# d is the review and c is category
featuresets = [(document_features(d), c) for (d,c) in documents]
featuresets[0]
#first 100 would be the test set 
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
featuresets[0]
# Out:
# ({'contains(break)': True,
#   'contains(remake)': False,
#   "contains((',', 'what'))": False,
#   'contains(brothers)': False,
#   'contains(old)': False,
#   'contains(feature)': False,
#   'contains(rescue)': False,
#   'contains(teen)': False,
#   "contains(('last', 'summer'))": False,
#   'contains(mel)': False,
#   "contains(('in', 'an'))": False,
#   'contains(decided)': False,
#   'contains(--)': False,
#   "contains((',', 'has'))": False,
#   'contains(help)': False,
#   "contains(('easy', 'to'))": False,
#   'contains(lawyer)': False,
#   "contains(('one', 'scene'))": False,
#   "contains(('.', 'just'))": False,
#   "contains(('about', 'to'))": False,
#   "contains(('lot', 'of'))": False,
#   "contains(('and', 'are'))": False,
#   "contains(('these', 'are'))": False,
#   "contains(('the', 'point'))": False,
#   'contains(will)': False,
#   'contains(climax)': False,
#   'contains(campbell)': False,
#   "contains(('it', 'does'))": False,
#   "contains(('films', 'like'))": False,
#   'contains(normal)': False,
#   "contains(('s', 'not'))": False,
#   "contains(('to', 'this'))": False,
#   "contains(('is', 'so'))": False,
#   "contains(('the', 'greatest'))": False,
#   "contains(('about', 'as'))": False,
#   "contains(('about', '.'))": False,
#   "contains(('home', ','))": False,
#   'contains(100)': False,
#   'contains(board)': False,
#   'contains(stay)': False,
#   "contains(('it', 'off'))": False,
#   "contains(('see', 'a'))": False,
#   "contains(('still', ','))": True,
#   'contains(were)': True,
#   'contains(was)': True,
#   'contains(typical)': False,
#   "contains(('the', 'other'))": False,
#   'contains(complete)': False,
#   'contains(apparently)': True,
#   'contains(giving)': False,
#   'contains(work)': False,
#   'contains(she)': False,
#   "contains(('s', '.'))": False,
#   "contains(('is', 'this'))": False,
#   'contains(allen)': False,
#   'contains(acting)': True,
#   "contains(('.', 'however'))": True,
#   'contains(highly)': False,
#   'contains(monster)': False,
#   "contains(('long', 'time'))": False,
#   'contains(film)': True,
#   'contains(enough)': False,
#   "contains(('he', 'will'))": False,
#   'contains(theater)': False,
#   'contains(favorite)': False,
#   "contains(('you', 'can'))": False,
#   'contains(yet)': True,
#   'contains(brings)': False,
#   "contains((',', 'much'))": False,
#   "contains((',', '000'))": False,
#   'contains(group)': False,
#   "contains(('times', ','))": False,
#   'contains(jay)': False,
#   'contains(task)': False,
#   "contains(('pretty', 'much'))": False,
#   "contains(('effects', '.'))": False,
#   'contains(around)': False,
#   "contains(('level', 'of'))": False,
#   "contains(('these', 'characters'))": False,
#   "contains(('to', 'say'))": False,
#   "contains(('again', '.'))": False,
#   "contains(('is', 'very'))": False,
#   'contains(conclusion)': False,
#   'contains(straight)': False,
#   "contains(('begin', 'to'))": False,
#   'contains(due)': True,
#   "contains(('over', '-'))": False,
#   "contains(('a', 'very'))": False,
#   "contains(('?', 'the'))": False,
#   'contains(past)': False,
#   "contains(('other', 'hand'))": False,
#   'contains(going)': False,
#   'contains(public)': False,
#   'contains(gibson)': False,
#   "contains(('screen', ','))": False,
#   'contains(horror)': False,
#   'contains(hurt)': False,
#   "contains(('to', 'find'))": False,
#   'contains(message)': False,
#   "contains(('it', 'should'))": False,
#   'contains(brian)': False,
#   "contains(('the', 'very'))": False,
#   'contains(neither)': False,
#   'contains(dennis)': False,
#   "contains(('plot', ':'))": False,
#   'contains(fox)': False,
#   'contains(set)': False,
#   "contains(('be', 'in'))": False,
#   'contains(visit)': False,
#   "contains(('back', 'and'))": False,
#   "contains(('never', 'been'))": False,
#   "contains(('into', 'the'))": False,
#   "contains(('end', 'up'))": False,
#   "contains(('to', 'have'))": False,
#   'contains(second)': False,
#   'contains(obvious)': False,
#   "contains((',', 'of'))": False,
#   "contains((',', 'after'))": False,
#   "contains(('happens', 'to'))": False,
#   "contains(('he', 'is'))": False,
#   "contains(('back', ','))": True,
#   "contains(('not', 'that'))": False,
#   "contains(('makes', 'the'))": False,
#   'contains(jason)': False,
#   'contains(mediocre)': False,
#   'contains(discovers)': False,
#   'contains(ultimately)': False,
#   "contains(('made', 'the'))": False,
#   "contains(('will', 'be'))": False,
#   'contains(position)': False,
#   "contains(('in', 'many'))": False,
#   "contains(('for', '.'))": False,
#   'contains(start)': False,
#   "contains(('.', 'since'))": False,
#   'contains(earth)': False,
#   "contains(('dialogue', 'is'))": False,
#   'contains(cop)': False,
#   'contains(top)': False,
#   "contains(('not', 'only'))": True,
#   "contains(('that', 'it'))": False,
#   "contains(('and', 'make'))": False,
#   "contains(('the', 'young'))": False,
#   'contains(animals)': False,
#   'contains(exception)': False,
#   'contains(music)': False,
#   "contains(('the', 'plot'))": True,
#   'contains(loving)': False,
#   "contains(('this', 'one'))": False,
#   "contains(('people', 'in'))": False,
#   'contains(ok)': False,
#   "contains(('too', 'long'))": False,
#   'contains(directing)': False,
#   "contains(('up', 'for'))": False,
#   'contains(could)': False,
#   'contains(believable)': False,
#   'contains(anti)': False,
#   'contains(anyway)': False,
#   'contains(sean)': False,
#   'contains(chinese)': False,
#   'contains(lot)': False,
#   'contains(entirely)': False,
#   "contains(('.', 'these'))": False,
#   "contains(('plenty', 'of'))": False,
#   'contains(cover)': False,
#   "contains(('bit', 'of'))": False,
#   "contains(('.', 'there'))": False,
#   "contains(('through', 'a'))": False,
#   "contains(('example', 'of'))": False,
#   'contains(dance)': False,
#   "contains(('end', ','))": False,
#   'contains(none)': False,
#   "contains(('two', 'of'))": False,
#   "contains((',', 'was'))": False,
#   'contains(light)': False,
#   'contains(crime)': False,
#   "contains(('when', 'i'))": False,
#   'contains(serious)': False,
#   "contains(('of', 'humor'))": False,
#   "contains(('we', 'have'))": False,
#   'contains(career)': False,
#   'contains(green)': False,
#   "contains(('however', ','))": True,
#   'contains(member)': False,
#   "contains(('what', 'they'))": False,
#   "contains(('a', 'time'))": False,
#   'contains(wants)': False,
#   "contains((',', 'at'))": False,
#   'contains(shame)': False,
#   "contains(('s', 'most'))": False,
#   'contains(t)': True,
#   'contains((\'man\', "\'"))': False,
#   "contains(('not', 'as'))": False,
#   "contains(('the', 'movie'))": True,
#   "contains(('seen', 'in'))": False,
#   "contains(('her', 'own'))": False,
#   "contains(('had', 'the'))": False,
#   'contains(buy)': False,
#   "contains(('and', 'his'))": True,
#   'contains(realized)': False,
#   'contains(90)': False,
#   "contains(('city', '.'))": False,
#   "contains(('not', 'be'))": False,
#   "contains(('the', 'cast'))": False,
#   'contains(fighting)': False,
#   'contains(five)': False,
#   "contains(('is', 'almost'))": False,
#   'contains(basic)': False,
#   'contains(home)': False,
#   "contains(('with', 'him'))": False,
#   "contains(('could', 'have'))": False,
#   "contains(('the', 'script'))": False,
#   'contains(review)': True,
#   'contains(growing)': False,
#   'contains(indeed)': False,
#   "contains(('just', 'the'))": False,
#   "contains(('all', 'this'))": False,
#   'contains((\'we\', "\'"))': False,
#   'contains(added)': False,
#   "contains(('clich', '?'))": False,
#   "contains(('must', 'have'))": False,
#   'contains(fly)': False,
#   'contains(no)': False,
#   'contains(10)': False,
#   'contains(title)': False,
#   'contains(ten)': False,
#   'contains(moments)': False,
#   "contains(('the', 'love'))": False,
#   "contains(('the', 'head'))": False,
#   'contains(proves)': False,
#   "contains(('are', 'no'))": False,
#   'contains(dying)': False,
#   'contains(approach)': False,
#   'contains(attractive)': False,
#   "contains(('a', 'woman'))": False,
#   "contains(('you', 'to'))": False,
#   'contains(watching)': False,
#   'contains(does)': False,
#   "contains(('is', 'a'))": False,
#   "contains(('but', 'this'))": False,
#   'contains((\'aren\', "\'"))': False,
#   'contains(design)': False,
#   'contains(grows)': False,
#   'contains(dude)': False,
#   "contains(('takes', 'place'))": False,
#   'contains(case)': False,
#   "contains(('get', 'the'))": False,
#   "contains(('she', 'can'))": False,
#   'contains(("\'", \'d\'))': False,
#   'contains(robin)': True,
#   "contains((',', 'most'))": False,
#   "contains(('and', 'it'))": False,
#   'contains(other)': False,
#   "contains((';', 'he'))": False,
#   "contains(('the', 'guy'))": False,
#   "contains(('a', 'real'))": False,
#   'contains(silent)': False,
#   'contains(imagination)': False,
#   "contains(('may', 'have'))": False,
#   'contains(conflict)': False,
#   'contains(beautiful)': False,
#   'contains(ups)': False,
#   'contains(art)': False,
#   'contains(kind)': False,
#   'contains(a)': True,
#   "contains(('scene', '.'))": False,
#   'contains(apartment)': True,
#   'contains(changes)': False,
#   "contains(('to', 'life'))": False,
#   "contains(('they', 'can'))": False,
#   'contains(j)': False,
#   'contains(felt)': True,
#   "contains(('not', '.'))": False,
#   'contains(match)': False,
#   'contains(personality)': False,
#   "contains(('because', 'she'))": False,
#   "contains(('was', 'a'))": False,
#   "contains(('.', 'maybe'))": False,
#   'contains(double)': False,
#   'contains(,)': True,
#   'contains(bring)': False,
#   'contains(children)': False,
#   'contains((\'of\', \'"\'))': False,
#   'contains(mars)': False,
#   'contains(twist)': False,
#   'contains(comedy)': False,
#   "contains(('ve', 'seen'))": False,
#   'contains(visually)': False,
#   "contains(('so', 'far'))": False,
#   'contains(wonder)': False,
#   "contains((')', ';'))": False,
#   "contains(('is', 'also'))": False,
#   'contains(blade)': False,
#   "contains(('it', 'has'))": False,
#   "contains(('in', 'addition'))": False,
#   "contains(('turns', 'out'))": False,
#   "contains(('it', '?'))": False,
#   'contains(13)': False,
#   'contains(mystery)': False,
#   'contains(films)': False,
#   'contains(for)': True,
#   "contains(('gets', 'the'))": False,
#   'contains(hilarious)': False,
#   "contains(('as', 'if'))": False,
#   "contains(('who', 'is'))": False,
#   'contains(likable)': False,
#   "contains(('s', 'wife'))": False,
#   'contains(physical)': False,
#   'contains(occasionally)': False,
#   'contains(sets)': False,
#   'contains(family)': False,
#   'contains(james)': False,
#   'contains(rock)': False,
#   'contains(1997)': False,
#   'contains(reasons)': False,
#   "contains(('do', '.'))": False,
#   "contains(('because', 'the'))": False,
#   'contains(read)': False,
#   "contains(('films', 'are'))": False,
#   "contains(('and', 'what'))": False,
#   "contains(('see', 'this'))": False,
#   "contains(('the', 'people'))": False,
#   "contains(('is', 'now'))": False,
#   'contains(aspects)': False,
#   'contains(really)': True,
#   "contains(('on', 'earth'))": False,
#   'contains(etc)': True,
#   "contains(('place', '.'))": False,
#   'contains(laughable)': False,
#   'contains(talk)': False,
#   "contains(('the', 'actors'))": False,
#   'contains(feeling)': False,
#   "contains(('the', 'theater'))": False,
#   "contains(('.', 'every'))": False,
#   "contains(('anyone', 'who'))": False,
#   "contains((',', 'he'))": False,
#   'contains(about)': False,
#   "contains(('and', 'its'))": False,
#   'contains(hanks)': False,
#   "contains(('wanted', 'to'))": False,
#   "contains(('with', 'this'))": False,
#   "contains(('after', 'the'))": False,
#   'contains(hill)': False,
#   'contains(detective)': False,
#   'contains(helps)': False,
#   'contains(depth)': False,
#   "contains(('movies', '.'))": False,
#   "contains(('a', 'bad'))": False,
#   'contains(myers)': False,
#   'contains(becomes)': False,
#   'contains(frank)': False,
#   "contains(('with', 'their'))": False,
#   'contains(screen)': False,
#   "contains(('of', 'being'))": False,
#   'contains(change)': False,
#   "contains(('takes', 'a'))": False,
#   "contains(('meanwhile', ','))": False,
#   'contains(worst)': False,
#   "contains(('minutes', '.'))": False,
#   "contains(('and', 'not'))": False,
#   "contains(('.', 'when'))": False,
#   'contains(steven)': True,
#   "contains(('better', 'than'))": False,
#   'contains(seconds)': False,
#   'contains(down)': False,
#   'contains(&)': False,
#   "contains(('i', '.'))": False,
#   "contains(('keep', 'the'))": False,
#   'contains(speech)': False,
#   'contains(hair)': False,
#   'contains(asks)': False,
#   "contains(('looking', 'for'))": False,
#   'contains(seat)': False,
#   'contains(tarzan)': False,
#   "contains(('goes', 'on'))": False,
#   'contains((\'"\', \'what\'))': False,
#   "contains(('have', 'seen'))": False,
#   "contains(('plot', 'is'))": True,
#   "contains(('we', 'know'))": False,
#   'contains(city)': False,
#   "contains(('day', ','))": True,
#   'contains(device)': False,
#   "contains(('is', 'simply'))": False,
#   'contains(comes)': True,
#   "contains(('do', 'you'))": False,
#   'contains(culture)': False,
#   'contains(goal)': False,
#   'contains((\'wasn\', "\'"))': False,
#   "contains(('the', 'case'))": False,
#   'contains((\'"\', \'which\'))': False,
#   'contains(tell)': False,
#   'contains(lucky)': False,
#   "contains(('.', 'his'))": False,
#   'contains(hold)': False,
#   "contains(('.', 'and'))": True,
#   'contains(jedi)': False,
#   "contains(('anyway', ','))": False,
#   'contains(hours)': False,
#   'contains(comparison)': False,
#   "contains(('that', 'was'))": False,
#   "contains(('ve', 'been'))": False,
#   "contains(('that', 'has'))": False,
#   'contains(first)': True,
#   "contains(('where', 'they'))": False,
#   'contains(saw)': True,
#   "contains(('not', 'sure'))": False,
#   'contains(presence)': False,
#   'contains(starts)': False,
#   "contains(('exactly', 'what'))": False,
#   'contains(6)': False,
#   "contains((':', 'the'))": False,
#   'contains(hopes)': False,
#   'contains(control)': False,
#   "contains(('.', '('))": False,
#   'contains(search)': False,
#   "contains(('t', 'like'))": False,
#   "contains(('more', 'like'))": False,
#   "contains(('s', 'just'))": False,
#   "contains(('not', 'have'))": False,
#   "contains(('and', 'in'))": False,
#   "contains(('but', 'it'))": True,
#   'contains(certainly)': False,
#   'contains(captain)': False,
#   "contains(('same', 'time'))": False,
#   "contains(('(', 'who'))": False,
#   'contains(reading)': False,
#   "contains(('even', 'more'))": False,
#   "contains(('good', ','))": False,
#   'contains(slasher)': False,
#   'contains(order)': False,
#   'contains(hits)': False,
#   "contains(('.', 'during'))": False,
#   'contains(lack)': False,
#   'contains(fails)': False,
#   'contains(standing)': False,
#   "contains(('which', 'he'))": False,
#   "contains(('-', 'old'))": False,
#   "contains(('are', 'in'))": False,
#   "contains(('the', 'effects'))": False,
#   "contains(('a', 'young'))": False,
#   'contains(quick)': False,
#   "contains(('if', 'you'))": True,
#   "contains(('but', 'then'))": False,
#   "contains((',', 'from'))": False,
#   "contains(('i', 'love'))": False,
#   "contains(('at', 'a'))": True,
#   "contains(('to', 'a'))": False,
#   'contains(nicely)': False,
#   "contains(('by', 'the'))": False,
#   'contains(loud)': False,
#   "contains(('character', 'in'))": False,
#   'contains(powers)': False,
#   "contains((',', 'this'))": False,
#   "contains(('is', 'only'))": False,
#   "contains(('picture', '.'))": False,
#   'contains(brown)': False,
#   'contains(last)': False,
#   'contains(needed)': False,
#   'contains(-)': True,
#   'contains(model)': False,
#   'contains(into)': True,
#   'contains(many)': True,
#   "contains(('is', 'really'))": False,
#   'contains(having)': True,
#   "contains(('with', 'an'))": False,
#   "contains((',', 'don'))": False,
#   "contains((',', 'that'))": True,
#   "contains(('role', 'as'))": False,
#   'contains(us)': False,
#   'contains(poorly)': False,
#   "contains(('he', 'could'))": False,
#   'contains(lines)': False,
#   'contains(willing)': True,
#   "contains(('attempt', 'to'))": False,
#   "contains(('himself', ','))": False,
#   'contains(realistic)': False,
#   'contains(big)': True,
#   'contains(zero)': False,
#   'contains(super)': True,
#   "contains(('the', 'american'))": False,
#   'contains(popular)': False,
#   'contains(extra)': False,
#   "contains(('want', 'to'))": True,
#   'contains(society)': False,
#   'contains(anderson)': False,
#   "contains(('you', 'get'))": False,
#   'contains(pace)': False,
#   'contains(brilliant)': False,
#   "contains(('was', 'so'))": False,
#   "contains(('case', 'of'))": False,
#   "contains(('place', 'in'))": False,
#   'contains(opposite)': False,
#   "contains(('the', 'life'))": False,
#   'contains(costumes)': False,
#   'contains(ice)': False,
#   "contains(('is', 'not'))": False,
#   "contains((',', 'on'))": False,
#   'contains(gay)': False,
#   "contains(('co', '-'))": False,
#   "contains(('along', 'with'))": False,
#   "contains(('humor', ','))": False,
#   'contains(al)': False,
#   "contains(('though', ','))": False,
#   "contains(('but', 'they'))": False,
#   "contains(('it', 'may'))": False,
#   'contains(whether)': False,
#   'contains(had)': True,
#   "contains(('the', 'dark'))": False,
#   'contains([)': False,
#   "contains(('film', '('))": False,
#   "contains(('blair', 'witch'))": False,
#   "contains(('group', 'of'))": False,
#   "contains(('based', 'on'))": False,
#   'contains(thankfully)': False,
#   'contains((\'is\', \'"\'))': False,
#   "contains(('it', 'for'))": False,
#   "contains(('he', 'gets'))": False,
#   'contains(again)': False,
#   "contains(('what', 'was'))": False,
#   'contains(cheesy)': False,
#   'contains(happening)': False,
#   "contains(('.', 'both'))": False,
#   'contains(working)': False,
#   'contains(names)': False,
#   'contains(gold)': False,
#   'contains(ends)': False,
#   'contains(open)': False,
#   'contains(worthy)': False,
#   "contains(('problem', 'with'))": False,
#   'contains(original)': False,
#   'contains(guard)': False,
#   'contains(carrey)': True,
#   "contains(('must', 'be'))": False,
#   "contains(('a', 'plot'))": False,
#   "contains(('s', 'character'))": False,
#   "contains(('a', 'large'))": False,
#   'contains(matters)': False,
#   "contains(('-', 'looking'))": False,
#   "contains(('one', ','))": False,
#   "contains(('the', 'killer'))": False,
#   'contains(trailer)': False,
#   "contains(('this', 'year'))": False,
#   "contains(('does', '.'))": False,
#   "contains((',', 'leaving'))": False,
#   'contains(hit)': False,
#   "contains(('/', 'director'))": False,
#   "contains(('the', 'title'))": False,
#   "contains(('the', 'next'))": False,
#   "contains((',', 'so'))": False,
#   "contains(('some', 'of'))": True,
#   'contains(crew)': False,
#   'contains(dramatic)': True,
#   'contains(states)': False,
#   "contains(('so', 'i'))": False,
#   "contains(('over', 'the'))": False,
#   "contains(('.', 'then'))": False,
#   'contains(already)': False,
#   'contains(expecting)': False,
#   'contains(dead)': False,
#   'contains(something)': True,
#   'contains(fair)': False,
#   "contains((',', 'despite'))": False,
#   "contains(('know', 'what'))": False,
#   "contains(('relationship', 'with'))": False,
#   "contains(('the', 'action'))": False,
#   "contains(('world', '.'))": False,
#   "contains(('despite', 'the'))": False,
#   'contains(yeah)': False,
#   "contains(('people', 'are'))": False,
#   "contains(('that', 'a'))": False,
#   'contains(pay)': False,
#   "contains(('a', 'half'))": False,
#   "contains(('scene', 'in'))": False,
#   'contains(four)': False,
#   "contains((',', 'their'))": False,
#   "contains(('.', '?'))": False,
#   'contains(accent)': False,
#   'contains(battle)': False,
#   "contains(('another', '.'))": False,
#   "contains(('re', '-'))": False,
#   "contains(('of', 'his'))": False,
#   'contains(box)': True,
#   'contains(inevitable)': False,
#   'contains((\'character\', "\'"))': False,
#   "contains(('all', 'of'))": False,
#   'contains(troopers)': False,
#   'contains(times)': False,
#   "contains(('for', 'this'))": False,
#   "contains(('up', '.'))": False,
#   "contains(('for', 'one'))": False,
#   'contains(patch)': False,
#   "contains(('.', ','))": False,
#   "contains(('things', 'that'))": False,
#   'contains(kong)': False,
#   "contains(('a', 'better'))": False,
#   "contains(('action', 'sequences'))": False,
#   'contains(gangster)': False,
#   "contains(('has', 'become'))": False,
#   'contains(stephen)': False,
#   'contains(cult)': False,
#   'contains(content)': False,
#   'contains(sharp)': False,
#   "contains(('when', 'a'))": False,
#   "contains(('sort', 'of'))": False,
#   "contains(('with', 'the'))": False,
#   'contains(example)': False,
#   "contains(('into', 'his'))": False,
#   'contains(target)': False,
#   'contains(together)': False,
#   'contains(sequence)': False,
#   "contains(('that', ','))": False,
#   'contains(tv)': True,
#   'contains(these)': True,
#   'contains(which)': True,
#   'contains(walking)': False,
#   "contains(('i', 'did'))": False,
#   'contains(l)': False,
#   "contains((')', 'to'))": False,
#   'contains(reveal)': False,
#   "contains(('its', 'own'))": False,
#   'contains((\'who\', "\'"))': False,
#   'contains(results)': True,
#   "contains(('bad', 'guys'))": False,
#   'contains(claire)': False,
#   "contains((',', 'yet'))": True,
#   "contains(('managed', 'to'))": False,
#   'contains(they)': False,
#   'contains(led)': False,
#   "contains(('that', 'one'))": False,
#   'contains(view)': False,
#   'contains(blame)': False,
#   "contains(('but', 'if'))": False,
#   "contains(('with', 'a'))": False,
#   "contains(('gets', 'a'))": False,
#   "contains(('the', 'alien'))": False,
#   'contains(considering)': False,
#   "contains(('scene', 'where'))": False,
#   'contains(promise)': False,
#   'contains(absolutely)': False,
#   'contains(isn)': False,
#   'contains(julie)': False,
#   'contains(pg)': False,
#   "contains(('which', 'makes'))": False,
#   "contains(('s', 'best'))": False,
#   "contains(('more', 'to'))": False,
#   "contains(('as', 'you'))": False,
#   'contains(age)': False,
#   "contains(('any', 'of'))": False,
#   'contains(paul)': False,
#   "contains(('in', 'fact'))": False,
#   "contains(('find', 'a'))": False,
#   "contains(('day', '.'))": True,
#   'contains(wayne)': False,
#   'contains(cannot)': False,
#   "contains(('have', 'the'))": False,
#   'contains(bunch)': False,
#   "contains(('no', 'one'))": False,
#   "contains(('bad', '.'))": False,
#   'contains(russell)': False,
#   'contains(ride)': False,
#   'contains(recently)': False,
#   'contains(stuart)': False,
#   'contains(episode)': False,
#   "contains(('are', ','))": False,
#   'contains(places)': False,
#   'contains(community)': False,
#   'contains(during)': True,
#   "contains(('who', ','))": False,
#   "contains(('but', 'as'))": False,
#   "contains(('once', 'again'))": False,
#   "contains(('the', 'question'))": False,
#   'contains(century)': False,
#   "contains(('a', '-'))": False,
#   'contains(hot)': True,
#   'contains(side)': True,
#   "contains(('the', 'viewer'))": False,
#   "contains(('-', 'life'))": False,
#   "contains(('look', 'like'))": False,
#   'contains(government)': False,
#   "contains(('and', 'to'))": True,
#   "contains((',', 'instead'))": False,
#   'contains(plays)': True,
#   'contains(travel)': False,
#   'contains(substance)': False,
#   'contains(extreme)': False,
#   "contains(('back', '.'))": False,
#   "contains(('can', 'do'))": False,
#   "contains(('the', 'middle'))": False,
#   'contains(older)': False,
#   'contains(barely)': False,
#   'contains(park)': False,
#   "contains(('with', 'one'))": False,
#   'contains(ray)': False,
#   'contains(necessary)': False,
#   "contains(('like', 'a'))": False,
#   'contains(stop)': False,
#   'contains(slowly)': False,
#   'contains(director)': False,
#   "contains(('supposed', 'to'))": True,
#   "contains(('plot', ','))": False,
#   "contains(('gives', 'us'))": False,
#   "contains(('s', 'more'))": False,
#   "contains(('.', 'their'))": False,
#   'contains(hardly)': False,
#   'contains(some)': True,
#   "contains(('.', 'that'))": False,
#   'contains(boss)': False,
#   'contains(mother)': False,
#   'contains((\'i\', "\'"))': True,
#   "contains(('.', 'to'))": False,
#   'contains(manages)': False,
#   "contains(('when', 'the'))": False,
#   'contains((\'haven\', "\'"))': False,
#   'contains(fan)': False,
#   "contains(('movie', 'with'))": False,
#   "contains(('ve', 'ever'))": False,
#   "contains(('his', 'best'))": True,
#   "contains(('for', 'all'))": False,
#   "contains(('the', 'police'))": False,
#   'contains(scenes)': True,
#   "contains(('problem', 'is'))": False,
#   "contains(('-', 'the'))": False,
#   "contains(('.', 'some'))": False,
#   'contains(faces)': False,
#   "contains(('-', 'be'))": False,
#   "contains(('out', '.'))": True,
#   "contains(('that', 'makes'))": False,
#   "contains(('performance', ','))": False,
#   "contains(('the', 'time'))": False,
#   'contains((\'that\', \'"\'))': False,
#   'contains(out)': True,
#   'contains(lame)': False,
#   'contains(should)': True,
#   'contains(definitely)': False,
#   'contains(appearance)': False,
#   "contains(('it', 'with'))": False,
#   'contains(snake)': False,
#   'contains(creature)': False,
#   "contains(('if', 'the'))": False,
#   "contains(('not', 'to'))": False,
#   "contains(('fun', '.'))": False,
#   "contains(('.', 'first'))": False,
#   "contains((',', 'like'))": True,
#   "contains(('else', '.'))": False,
#   "contains(('and', 'at'))": False,
#   'contains(forced)': False,
#   'contains(less)': True,
#   "contains(('the', 'planet'))": False,
#   'contains(move)': False,
#   'contains(plan)': False,
#   'contains(professional)': False,
#   "contains(('.', 'john'))": False,
#   "contains(('difficult', 'to'))": False,
#   'contains(step)': False,
#   "contains(('attempts', 'to'))": False,
#   'contains(predictable)': False,
#   'contains(complex)': False,
#   "contains(('.', 'everything'))": False,
#   'contains(honest)': False,
#   "contains(('and', 'i'))": True,
#   "contains(('and', 'the'))": False,
#   'contains(flying)': False,
#   'contains(kids)': False,
#   'contains(ridiculous)': False,
#   'contains(award)': False,
#   'contains(their)': False,
#   "contains(('even', 'a'))": False,
#   'contains(plans)': False,
#   'contains(adds)': False,
#   'contains((\'"\', \'that\'))': False,
#   'contains(social)': False,
#   "contains(('deal', 'with'))": False,
#   "contains(('in', 'that'))": False,
#   'contains(miller)': False,
#   "contains(('comes', 'to'))": False,
#   'contains(larry)': True,
#   "contains(('the', 'good'))": False,
#   "contains(('at', 'least'))": False,
#   "contains((',', 'such'))": False,
#   "contains(('would', 'be'))": False,
#   "contains(('make', 'a'))": False,
#   'contains(continues)': False,
#   'contains(spends)': False,
#   'contains(engaging)': False,
#   'contains(video)': True,
#   "contains(('up', 'and'))": False,
#   "contains(('seen', 'the'))": False,
#   "contains(('also', 'a'))": False,
#   'contains(british)': False,
#   'contains(fake)': False,
#   'contains(whose)': False,
#   "contains((',', 'the'))": True,
#   "contains(('but', 'he'))": False,
#   "contains(('the', 'show'))": False,
#   "contains(('it', 'up'))": False,
#   'contains(poor)': False,
#   "contains(('experience', '.'))": False,
#   "contains(('see', 'the'))": False,
#   'contains(/)': False,
#   "contains(('is', 'the'))": False,
#   'contains(average)': False,
#   'contains(loses)': False,
#   'contains(please)': False,
#   'contains(slightly)': False,
#   'contains(managed)': False,
#   'contains(begins)': False,
#   'contains(state)': False,
#   'contains(cinematic)': False,
#   'contains(love)': True,
#   'contains(try)': True,
#   'contains(daughter)': False,
#   'contains(shooting)': False,
#   'contains(winning)': False,
#   "contains(('down', '.'))": False,
#   'contains(haunting)': False,
#   "contains(('the', 'idea'))": False,
#   "contains(('looks', 'like'))": False,
#   "contains((',', 'except'))": False,
#   "contains(('type', 'of'))": False,
#   'contains(particularly)': True,
#   'contains(extremely)': False,
#   "contains(('enough', 'to'))": False,
#   'contains(determined)': False,
#   "contains(('actor', ','))": False,
#   'contains(runs)': False,
#   'contains(history)': False,
#   'contains(similar)': False,
#   'contains(scientist)': False,
#   'contains(country)': False,
#   "contains(('-', 'year'))": False,
#   'contains(credit)': False,
#   'contains(things)': False,
#   "contains(('that', 'are'))": False,
#   "contains(('only', 'the'))": False,
#   "contains(('to', 'that'))": False,
#   'contains(taste)': False,
#   'contains(enjoyed)': False,
#   "contains(('you', '.'))": False,
#   "contains(('one', 'day'))": False,
#   'contains(nowhere)': False,
#   "contains((',', 'we'))": False,
#   "contains((',', 'well'))": True,
#   'contains(science)': False,
#   "contains(('movie', 'that'))": False,
#   'contains(night)': False,
#   'contains(presented)': False,
#   "contains(('stars', 'as'))": False,
#   'contains(meeting)': False,
#   "contains(('t', 'want'))": False,
#   'contains(dreams)': False,
#   "contains(('fails', 'to'))": False,
#   'contains((\'"\', \')\'))': False,
#   "contains(('off', 'as'))": False,
#   'contains(tony)': False,
#   'contains((\'year\', "\'"))': False,
#   'contains(stuff)': False,
#   "contains(('(', 'a'))": True,
#   "contains(('movie', 'has'))": False,
#   "contains(('-', 'in'))": False,
#   "contains(('show', '.'))": False,
#   "contains(('from', 'a'))": False,
#   "contains(('to', 'live'))": False,
#   'contains(truth)': False,
#   'contains(intense)': False,
#   "contains(('t', 'quite'))": False,
#   'contains(sound)': False,
#   "contains(('i', 'am'))": False,
#   'contains(attention)': False,
#   "contains(('a', 'man'))": False,
#   'contains(possibly)': False,
#   "contains(('to', 'stay'))": False,
#   'contains(funniest)': False,
#   "contains(('after', 'a'))": False,
#   'contains(beauty)': False,
#   "contains(('she', 'is'))": False,
#   "contains(('t', 'a'))": False,
#   'contains(leads)': False,
#   "contains(('but', 'there'))": False,
#   "contains(('i', 'guess'))": False,
#   "contains(('thing', 'that'))": False,
#   'contains(above)': False,
#   "contains(('as', 'we'))": False,
#   'contains(starring)': False,
#   "contains(('.', 'at'))": False,
#   'contains(dull)': False,
#   'contains(bond)': False,
#   'contains(powerful)': False,
#   "contains(('.', 'while'))": False,
#   "contains(('effects', ','))": False,
#   'contains(not)': True,
#   'contains(singer)': False,
#   'contains(you)': True,
#   'contains(black)': False,
#   "contains(('money', '.'))": False,
#   "contains(('come', 'to'))": False,
#   'contains(watched)': False,
#   'contains(gary)': False,
#   "contains(('he', 'and'))": False,
#   "contains(('forced', 'to'))": False,
#   'contains((\'won\', "\'"))': True,
#   'contains(nearly)': False,
#   'contains(why)': False,
#   'contains(entertainment)': True,
#   "contains(('but', 'to'))": False,
#   'contains(thought)': True,
#   'contains(town)': False,
#   'contains(father)': False,
#   "contains(('people', 'who'))": False,
#   'contains(course)': False,
#   'contains(storyline)': False,
#   "contains(('audience', ','))": False,
#   "contains(('characters', ','))": False,
#   "contains(('does', 'the'))": False,
#   'contains(fame)': False,
#   'contains(weird)': False,
#   "contains(('instead', 'of'))": False,
#   "contains(('and', 'there'))": False,
#   "contains(('the', 'film'))": True,
#   'contains(nights)': False,
#   'contains(law)': False,
#   'contains(creepy)': False,
#   "contains(('throughout', 'the'))": False,
#   "contains(('off', '.'))": False,
#   "contains(('the', 'two'))": False,
#   "contains(('work', '.'))": False,
#   'contains(writing)': False,
#   'contains(situations)': False,
#   "contains(('movie', 'to'))": False,
#   "contains(('know', 'that'))": False,
#   'contains(others)': False,
#   'contains(release)': False,
#   'contains(hunting)': False,
#   'contains(chemistry)': False,
#   'contains(makes)': True,
#   'contains(sub)': False,
#   "contains(('an', 'old'))": False,
#   'contains(girls)': False,
#   "contains(('get', 'to'))": False,
#   'contains(future)': False,
#   "contains(('later', ','))": False,
#   'contains(point)': False,
#   'contains(almost)': False,
#   'contains(knows)': True,
#   'contains(dealing)': False,
#   "contains(('and', 'then'))": False,
#   "contains(('as', 'to'))": False,
#   "contains(('ex', '-'))": False,
#   "contains(('one', '.'))": False,
#   'contains(trust)': False,
#   "contains(('fun', 'to'))": False,
#   "contains(('nothing', 'to'))": False,
#   'contains(b)': False,
#   "contains(('set', 'in'))": False,
#   "contains(('this', 'time'))": False,
#   'contains((\'they\', "\'"))': False,
#   'contains(upon)': False,
#   "contains(('a', 'bunch'))": False,
#   'contains(camp)': False,
#   "contains(('the', 'usual'))": False,
#   'contains(rocky)': False,
#   "contains(('time', '.'))": False,
#   'contains(yes)': False,
#   'contains(pretty)': False,
#   'contains(here)': False,
#   "contains((')', 'that'))": False,
#   "contains(('there', 'were'))": False,
#   'contains(impossible)': False,
#   "contains(('the', 'local'))": False,
#   'contains(lover)': False,
#   'contains(days)': False,
#   "contains(('the', 'scenes'))": False,
#   'contains((\'"\', \'in\'))': False,
#   "contains(('fact', 'that'))": True,
#   "contains(('much', 'as'))": False,
#   'contains(entertaining)': False,
#   'contains(creates)': False,
#   'contains(various)': True,
#   'contains(mostly)': False,
#   'contains(aspect)': False,
#   "contains((',', 'because'))": False,
#   "contains(('for', 'their'))": False,
#   'contains(tone)': False,
#   "contains(('to', 'look'))": False,
#   'contains(large)': False,
#   'contains(actors)': False,
#   'contains(mix)': False,
#   "contains(('to', 'become'))": False,
#   "contains(('that', 'can'))": False,
#   "contains(('i', 'was'))": True,
#   'contains(lead)': False,
#   'contains(individual)': True,
#   "contains(('how', 'much'))": False,
#   "contains(('as', 'in'))": False,
#   "contains(('but', 'the'))": False,
#   'contains(1996)': True,
#   "contains(('trying', 'to'))": False,
#   "contains((';', 'and'))": False,
#   'contains(fairly)': False,
#   'contains(fashion)': False,
#   'contains(ill)': False,
#   'contains(tough)': False,
#   ...},
#  'pos')

# %%
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.7

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
# contains(('waste', 'of')) = True              neg : pos    =     14.1 : 1.0
#    contains(outstanding) = True              pos : neg    =     13.3 : 1.0
#    contains(wonderfully) = True              pos : neg    =      7.6 : 1.0
#         contains(seagal) = True              neg : pos    =      7.4 : 1.0
# contains(('bad', 'movie')) = True              neg : pos    =      7.2 : 1.0
#          contains(damon) = True              pos : neg    =      5.9 : 1.0
#          contains(waste) = True              neg : pos    =      5.7 : 1.0
#          contains(flynt) = True              pos : neg    =      5.7 : 1.0
#          contains(awful) = True              neg : pos    =      5.4 : 1.0
#           contains(jedi) = True              pos : neg    =      5.3 : 1.0
#     contains(ridiculous) = True              neg : pos    =      5.3 : 1.0
#           contains(lame) = True              neg : pos    =      5.1 : 1.0
#         contains(wasted) = True              neg : pos    =      5.0 : 1.0
#         contains(poorly) = True              neg : pos    =      4.7 : 1.0
# contains(('too', 'bad')) = True              neg : pos    =      4.6 : 1.0
#          contains(worst) = True              neg : pos    =      4.5 : 1.0
#            contains(era) = True              pos : neg    =      4.4 : 1.0
#         contains(stupid) = True              neg : pos    =      4.3 : 1.0
# contains(('portrayal', 'of')) = True              pos : neg    =      4.3 : 1.0
#  contains(('s', 'life')) = True              pos : neg    =      4.2 : 1.0
#         contains(allows) = True              pos : neg    =      4.1 : 1.0
#        contains(unfunny) = True              neg : pos    =      4.1 : 1.0
#          contains(bland) = True              neg : pos    =      4.1 : 1.0
#           contains(dull) = True              neg : pos    =      4.1 : 1.0
# contains(('the', 'worst')) = True              neg : pos    =      3.9 : 1.0
#           contains(mess) = True              neg : pos    =      3.8 : 1.0
#      contains(memorable) = True              pos : neg    =      3.8 : 1.0
#      contains(portrayal) = True              pos : neg    =      3.7 : 1.0
#      contains(laughable) = True              neg : pos    =      3.7 : 1.0
#          contains(badly) = True              neg : pos    =      3.7 : 1.0

# %% [markdown]
# Now go to the internet, find a movie review, create a tokenized string out of it, and try to classify it!

# %% [markdown]
# Hint:

# %%
my_review = nltk.word_tokenize("too wasteful REVIEW")

# %%
rev_doc_feats = document_features(my_review)

# %%
classifier.classify(rev_doc_feats)
# Out:
# 'neg'

# %%
#scikit learn
#SVM - Ac
#random forest
#NN
